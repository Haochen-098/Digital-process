# %%
# !wget -q -nc https://raw.githubusercontent.com/pseprivamirakbarnejad/cmput206lab/master/Lab3/ex1.jpg
# !wget -q -nc https://raw.githubusercontent.com/pseprivamirakbarnejad/cmput206lab/master/Lab3/ex2.jpg
# !ls
# Out:
# ex1.jpg  ex2.jpg  sample_data

# %%
from skimage import io
from skimage.filters import sobel_h 
from skimage.filters import sobel_v
import numpy as np
from skimage.color import rgb2gray
import matplotlib.pyplot as plt

img = io.imread('ex2.jpg',True)  
img_g = np.zeros(img.shape)
plt.imshow(img,cmap='gray') 
plt.title("Original")
plt.show()
img_h = sobel_h(img)
plt.imshow(img_h,cmap='gray') 
plt.title("horizontal derivative images")
plt.show()
img_v = sobel_v(img)
plt.imshow(img_v,cmap='gray') 
plt.title("vertical derivative images")
plt.show()
height = img.shape[0]
width = img.shape[1]
for x in range(0,height):
  for y in range(0,width):
    img_g[x][y] = img_h[x][y]+img_v[x][y]
plt.imshow(img_g,cmap='gray') 
plt.title("gradient of the image")
plt.show()
